# %%
# Import Dependencies
import random
import numpy as np
from citipy import citipy
from config import weather_api_key
import pandas as pd
import requests
import pprint

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Build the URL
# Starting URL for Weather Map API Call.
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key
print(base_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=00e987282dc4e7a6f2e5e6eb49897e26

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
  
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
  # Create endpoint URL with each city.
    city_url = base_url + "&q=" + city.replace(" ","+")
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        #pprint.pprint(f"The weather API responded with: {city_weather}.")
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        City_description = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current_Description": City_description
                         })
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hamilton
# Processing Record 2 of Set 1 | narsaq
# Processing Record 3 of Set 1 | seryshevo
# Processing Record 4 of Set 1 | panguna
# Processing Record 5 of Set 1 | orange cove
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | harper
# Processing Record 8 of Set 1 | nemuro
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 1 | margate
# Processing Record 12 of Set 1 | jinchang
# Processing Record 13 of Set 1 | umri
# Processing Record 14 of Set 1 | kirs
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | faanui
# Processing Record 17 of Set 1 | airai
# Processing Record 18 of Set 1 | upernavik
# Processing Record 19 of Set 1 | gurgan
# City not found. Skipping...
# Processing Record 20 of Set 1 | hithadhoo
# Processing Record 21 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 1 | bengkulu
# Processing Record 23 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 1 | bambous virieux
# Processing Record 25 of Set 1 | omboue
# Processing Record 26 of Set 1 | vagur
# Processing Record 27 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 1 | mahebourg
# Processing Record 29 of Set 1 | salalah
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | klaksvik
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | brindisi
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | provideniya
# Processing Record 36 of Set 1 | conceicao do araguaia
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | teguldet
# Processing Record 39 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 1 | sao joao da barra
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | sechura
# Processing Record 43 of Set 1 | vestmannaeyjar
# Processing Record 44 of Set 1 | cienfuegos
# Processing Record 45 of Set 1 | banda aceh
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | mnogovershinnyy
# Processing Record 48 of Set 1 | ilulissat
# Processing Record 49 of Set 1 | muros
# Processing Record 50 of Set 1 | bone
# Processing Record 1 of Set 2 | nyurba
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | hervey bay
# Processing Record 4 of Set 2 | jarvakandi
# Processing Record 5 of Set 2 | nago
# Processing Record 6 of Set 2 | saskylakh
# Processing Record 7 of Set 2 | sao mateus
# Processing Record 8 of Set 2 | ponta do sol
# Processing Record 9 of Set 2 | dikson
# Processing Record 10 of Set 2 | saint-augustin
# Processing Record 11 of Set 2 | jiroft
# City not found. Skipping...
# Processing Record 12 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | port alfred
# Processing Record 15 of Set 2 | kavieng
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | northam
# Processing Record 18 of Set 2 | hasaki
# Processing Record 19 of Set 2 | port elizabeth
# Processing Record 20 of Set 2 | leningradskiy
# Processing Record 21 of Set 2 | antofagasta
# Processing Record 22 of Set 2 | lompoc
# Processing Record 23 of Set 2 | ahuimanu
# Processing Record 24 of Set 2 | kochki
# Processing Record 25 of Set 2 | takoradi
# Processing Record 26 of Set 2 | longyearbyen
# Processing Record 27 of Set 2 | markova
# Processing Record 28 of Set 2 | nikolskoye
# Processing Record 29 of Set 2 | mantua
# Processing Record 30 of Set 2 | tasiilaq
# Processing Record 31 of Set 2 | hushitai
# Processing Record 32 of Set 2 | manhush
# Processing Record 33 of Set 2 | abu zabad
# Processing Record 34 of Set 2 | sitka
# Processing Record 35 of Set 2 | qaqortoq
# Processing Record 36 of Set 2 | pandan
# Processing Record 37 of Set 2 | esperance
# Processing Record 38 of Set 2 | vila velha
# Processing Record 39 of Set 2 | robertsport
# Processing Record 40 of Set 2 | bograd
# Processing Record 41 of Set 2 | jamestown
# Processing Record 42 of Set 2 | flinders
# Processing Record 43 of Set 2 | port blair
# Processing Record 44 of Set 2 | khandyga
# Processing Record 45 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 2 | saint albans
# Processing Record 47 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 2 | oksfjord
# Processing Record 49 of Set 2 | braslav
# City not found. Skipping...
# Processing Record 50 of Set 2 | tabas
# Processing Record 1 of Set 3 | albany
# Processing Record 2 of Set 3 | alyangula
# Processing Record 3 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 3 | barrow
# Processing Record 5 of Set 3 | port hardy
# Processing Record 6 of Set 3 | dingle
# Processing Record 7 of Set 3 | grand-santi
# Processing Record 8 of Set 3 | port hedland
# Processing Record 9 of Set 3 | talnakh
# Processing Record 10 of Set 3 | mar del plata
# Processing Record 11 of Set 3 | tiksi
# Processing Record 12 of Set 3 | ushuaia
# Processing Record 13 of Set 3 | puerto ayora
# Processing Record 14 of Set 3 | norman wells
# Processing Record 15 of Set 3 | lorengau
# Processing Record 16 of Set 3 | bluff
# Processing Record 17 of Set 3 | garowe
# Processing Record 18 of Set 3 | usinsk
# Processing Record 19 of Set 3 | seoni malwa
# Processing Record 20 of Set 3 | kodiak
# Processing Record 21 of Set 3 | turukhansk
# Processing Record 22 of Set 3 | guerrero negro
# Processing Record 23 of Set 3 | katsuura
# Processing Record 24 of Set 3 | butaritari
# Processing Record 25 of Set 3 | kapaa
# Processing Record 26 of Set 3 | guhagar
# Processing Record 27 of Set 3 | cherskiy
# Processing Record 28 of Set 3 | jasper
# Processing Record 29 of Set 3 | adzope
# Processing Record 30 of Set 3 | srednekolymsk
# Processing Record 31 of Set 3 | atsiki
# City not found. Skipping...
# Processing Record 32 of Set 3 | port lincoln
# Processing Record 33 of Set 3 | new norfolk
# Processing Record 34 of Set 3 | kampot
# Processing Record 35 of Set 3 | la rioja
# Processing Record 36 of Set 3 | mabaruma
# Processing Record 37 of Set 3 | araouane
# Processing Record 38 of Set 3 | aksu
# Processing Record 39 of Set 3 | port-gentil
# Processing Record 40 of Set 3 | chuy
# Processing Record 41 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 3 | kloulklubed
# Processing Record 43 of Set 3 | pevek
# Processing Record 44 of Set 3 | chakulia
# Processing Record 45 of Set 3 | tilichiki
# Processing Record 46 of Set 3 | bekovo
# Processing Record 47 of Set 3 | avarua
# Processing Record 48 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 49 of Set 3 | westport
# Processing Record 50 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 4 | itajuba
# Processing Record 2 of Set 4 | saint-philippe
# Processing Record 3 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 4 | eureka
# Processing Record 5 of Set 4 | cayenne
# Processing Record 6 of Set 4 | sebrovo
# Processing Record 7 of Set 4 | alice springs
# Processing Record 8 of Set 4 | toamasina
# Processing Record 9 of Set 4 | hobart
# Processing Record 10 of Set 4 | yulara
# Processing Record 11 of Set 4 | los llanos de aridane
# Processing Record 12 of Set 4 | georgetown
# Processing Record 13 of Set 4 | mackay
# Processing Record 14 of Set 4 | goundi
# Processing Record 15 of Set 4 | rocha
# Processing Record 16 of Set 4 | saint-paul
# Processing Record 17 of Set 4 | talikota
# Processing Record 18 of Set 4 | campbell river
# Processing Record 19 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 4 | severo-kurilsk
# Processing Record 21 of Set 4 | atar
# Processing Record 22 of Set 4 | kirakira
# Processing Record 23 of Set 4 | chokurdakh
# Processing Record 24 of Set 4 | saldanha
# Processing Record 25 of Set 4 | berlevag
# Processing Record 26 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 4 | merauke
# Processing Record 28 of Set 4 | thompson
# Processing Record 29 of Set 4 | ancud
# Processing Record 30 of Set 4 | carnarvon
# Processing Record 31 of Set 4 | lebu
# Processing Record 32 of Set 4 | damghan
# Processing Record 33 of Set 4 | preobrazheniye
# Processing Record 34 of Set 4 | arraial do cabo
# Processing Record 35 of Set 4 | petrolandia
# City not found. Skipping...
# Processing Record 36 of Set 4 | salinopolis
# Processing Record 37 of Set 4 | sisimiut
# Processing Record 38 of Set 4 | kaitangata
# Processing Record 39 of Set 4 | chernyshevsk
# Processing Record 40 of Set 4 | gobabis
# Processing Record 41 of Set 4 | walvis bay
# Processing Record 42 of Set 4 | luderitz
# Processing Record 43 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 4 | necochea
# Processing Record 45 of Set 4 | morgan city
# Processing Record 46 of Set 4 | bethel
# Processing Record 47 of Set 4 | nargana
# Processing Record 48 of Set 4 | champerico
# Processing Record 49 of Set 4 | anchorage
# Processing Record 50 of Set 4 | pulandian
# Processing Record 1 of Set 5 | namwala
# Processing Record 2 of Set 5 | castro
# Processing Record 3 of Set 5 | qaanaaq
# Processing Record 4 of Set 5 | torbay
# Processing Record 5 of Set 5 | tuktoyaktuk
# Processing Record 6 of Set 5 | tuatapere
# Processing Record 7 of Set 5 | pandhana
# Processing Record 8 of Set 5 | muravlenko
# Processing Record 9 of Set 5 | sorong
# Processing Record 10 of Set 5 | ocos
# Processing Record 11 of Set 5 | dengzhou
# Processing Record 12 of Set 5 | emba
# Processing Record 13 of Set 5 | iqaluit
# Processing Record 14 of Set 5 | sao joao de pirabas
# Processing Record 15 of Set 5 | kissing
# Processing Record 16 of Set 5 | ixtapa
# Processing Record 17 of Set 5 | ribeira grande
# Processing Record 18 of Set 5 | oran
# Processing Record 19 of Set 5 | monrovia
# Processing Record 20 of Set 5 | susanino
# Processing Record 21 of Set 5 | haimen
# Processing Record 22 of Set 5 | nanortalik
# Processing Record 23 of Set 5 | zarand
# Processing Record 24 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 5 | acarau
# Processing Record 26 of Set 5 | constitucion
# Processing Record 27 of Set 5 | namibe
# Processing Record 28 of Set 5 | kavaratti
# Processing Record 29 of Set 5 | mananara
# Processing Record 30 of Set 5 | kruisfontein
# Processing Record 31 of Set 5 | scarborough
# Processing Record 32 of Set 5 | mouila
# Processing Record 33 of Set 5 | college
# Processing Record 34 of Set 5 | nome
# Processing Record 35 of Set 5 | dakoro
# Processing Record 36 of Set 5 | alofi
# Processing Record 37 of Set 5 | lazaro cardenas
# Processing Record 38 of Set 5 | khatanga
# Processing Record 39 of Set 5 | jos
# Processing Record 40 of Set 5 | cedar city
# Processing Record 41 of Set 5 | port augusta
# Processing Record 42 of Set 5 | zhigansk
# Processing Record 43 of Set 5 | port hueneme
# Processing Record 44 of Set 5 | rudraprayag
# Processing Record 45 of Set 5 | portland
# Processing Record 46 of Set 5 | maraba
# Processing Record 47 of Set 5 | monte alegre
# Processing Record 48 of Set 5 | hofn
# Processing Record 49 of Set 5 | lavrentiya
# Processing Record 50 of Set 5 | jumla
# Processing Record 1 of Set 6 | souillac
# Processing Record 2 of Set 6 | krasnoselkup
# Processing Record 3 of Set 6 | herat
# Processing Record 4 of Set 6 | san patricio
# Processing Record 5 of Set 6 | mazamari
# Processing Record 6 of Set 6 | manaure
# Processing Record 7 of Set 6 | pisco
# Processing Record 8 of Set 6 | meulaboh
# Processing Record 9 of Set 6 | shakiso
# Processing Record 10 of Set 6 | elsmere
# Processing Record 11 of Set 6 | huarmey
# Processing Record 12 of Set 6 | sorland
# Processing Record 13 of Set 6 | hambantota
# Processing Record 14 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 15 of Set 6 | geraldton
# Processing Record 16 of Set 6 | camana
# Processing Record 17 of Set 6 | saint-denis
# Processing Record 18 of Set 6 | ossora
# Processing Record 19 of Set 6 | beringovskiy
# Processing Record 20 of Set 6 | cockburn town
# Processing Record 21 of Set 6 | sao filipe
# Processing Record 22 of Set 6 | tecoanapa
# Processing Record 23 of Set 6 | bundaberg
# Processing Record 24 of Set 6 | bridlington
# Processing Record 25 of Set 6 | ikot ekpene
# Processing Record 26 of Set 6 | guerrero
# Processing Record 27 of Set 6 | vardo
# Processing Record 28 of Set 6 | pascagoula
# Processing Record 29 of Set 6 | ommen
# Processing Record 30 of Set 6 | mount gambier
# Processing Record 31 of Set 6 | lagoa
# Processing Record 32 of Set 6 | grindavik
# Processing Record 33 of Set 6 | bergen
# Processing Record 34 of Set 6 | manokwari
# Processing Record 35 of Set 6 | tignere
# Processing Record 36 of Set 6 | caravelas
# Processing Record 37 of Set 6 | east london
# Processing Record 38 of Set 6 | clyde river
# Processing Record 39 of Set 6 | reconquista
# Processing Record 40 of Set 6 | vanimo
# Processing Record 41 of Set 6 | sooke
# Processing Record 42 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 43 of Set 6 | kamaishi
# Processing Record 44 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 45 of Set 6 | san carlos de bariloche
# Processing Record 46 of Set 6 | surgut
# Processing Record 47 of Set 6 | coquimbo
# Processing Record 48 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 6 | guanambi
# Processing Record 50 of Set 6 | pacific grove
# Processing Record 1 of Set 7 | amahai
# Processing Record 2 of Set 7 | te anau
# Processing Record 3 of Set 7 | tevriz
# Processing Record 4 of Set 7 | birjand
# Processing Record 5 of Set 7 | gainesville
# Processing Record 6 of Set 7 | benavente
# Processing Record 7 of Set 7 | cidreira
# Processing Record 8 of Set 7 | seymour
# Processing Record 9 of Set 7 | fort nelson
# Processing Record 10 of Set 7 | nara
# Processing Record 11 of Set 7 | caceres
# Processing Record 12 of Set 7 | barguzin
# Processing Record 13 of Set 7 | manzhouli
# Processing Record 14 of Set 7 | ayan
# Processing Record 15 of Set 7 | we
# City not found. Skipping...
# Processing Record 16 of Set 7 | itoman
# Processing Record 17 of Set 7 | storsteinnes
# Processing Record 18 of Set 7 | puerto lopez
# Processing Record 19 of Set 7 | linares
# Processing Record 20 of Set 7 | kisaran
# Processing Record 21 of Set 7 | general roca
# Processing Record 22 of Set 7 | novikovo
# Processing Record 23 of Set 7 | vao
# Processing Record 24 of Set 7 | borlange
# City not found. Skipping...
# Processing Record 25 of Set 7 | trairi
# Processing Record 26 of Set 7 | kuala krai
# City not found. Skipping...
# Processing Record 27 of Set 7 | tautira
# Processing Record 28 of Set 7 | sinnamary
# Processing Record 29 of Set 7 | mastic beach
# Processing Record 30 of Set 7 | rio grande
# Processing Record 31 of Set 7 | christchurch
# Processing Record 32 of Set 7 | catamarca
# Processing Record 33 of Set 7 | paamiut
# Processing Record 34 of Set 7 | ekhabi
# Processing Record 35 of Set 7 | tehachapi
# Processing Record 36 of Set 7 | limbang
# Processing Record 37 of Set 7 | kidal
# Processing Record 38 of Set 7 | atambua
# Processing Record 39 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 7 | yar-sale
# Processing Record 41 of Set 7 | racine
# Processing Record 42 of Set 7 | nouadhibou
# Processing Record 43 of Set 7 | pervomayskiy
# Processing Record 44 of Set 7 | port macquarie
# Processing Record 45 of Set 7 | itarema
# Processing Record 46 of Set 7 | kulhudhuffushi
# Processing Record 47 of Set 7 | victoria
# Processing Record 48 of Set 7 | aybak
# City not found. Skipping...
# Processing Record 49 of Set 7 | kyshtovka
# Processing Record 50 of Set 7 | waipawa
# Processing Record 1 of Set 8 | leland
# Processing Record 2 of Set 8 | bin qirdan
# Processing Record 3 of Set 8 | hovd
# Processing Record 4 of Set 8 | saint-pierre
# Processing Record 5 of Set 8 | formosa
# Processing Record 6 of Set 8 | grand gaube
# Processing Record 7 of Set 8 | sedelnikovo
# City not found. Skipping...
# Processing Record 8 of Set 8 | kerema
# Processing Record 9 of Set 8 | derzhavinsk
# Processing Record 10 of Set 8 | ivanava
# Processing Record 11 of Set 8 | los planes
# Processing Record 12 of Set 8 | shumskiy
# Processing Record 13 of Set 8 | monatele
# City not found. Skipping...
# Processing Record 14 of Set 8 | tigil
# Processing Record 15 of Set 8 | mamallapuram
# Processing Record 16 of Set 8 | fortuna
# Processing Record 17 of Set 8 | ampanihy
# Processing Record 18 of Set 8 | inirida
# Processing Record 19 of Set 8 | mercedes
# Processing Record 20 of Set 8 | maura
# Processing Record 21 of Set 8 | yeniseysk
# Processing Record 22 of Set 8 | sur
# Processing Record 23 of Set 8 | martigues
# Processing Record 24 of Set 8 | avera
# Processing Record 25 of Set 8 | ulaangom
# Processing Record 26 of Set 8 | severodvinsk
# Processing Record 27 of Set 8 | eskisehir
# Processing Record 28 of Set 8 | laguna
# Processing Record 29 of Set 8 | kyaiklat
# Processing Record 30 of Set 8 | malanville
# Processing Record 31 of Set 8 | addi ugri
# City not found. Skipping...
# Processing Record 32 of Set 8 | alta floresta
# Processing Record 33 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 34 of Set 8 | ishigaki
# Processing Record 35 of Set 8 | vila franca do campo
# Processing Record 36 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 37 of Set 8 | broome
# Processing Record 38 of Set 8 | horuphav
# Processing Record 39 of Set 8 | kuito
# Processing Record 40 of Set 8 | coahuayana
# Processing Record 41 of Set 8 | buala
# Processing Record 42 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 8 | coihaique
# Processing Record 44 of Set 8 | zeya
# Processing Record 45 of Set 8 | berbera
# Processing Record 46 of Set 8 | bathsheba
# Processing Record 47 of Set 8 | faya
# Processing Record 48 of Set 8 | tazovskiy
# Processing Record 49 of Set 8 | prince albert
# Processing Record 50 of Set 8 | gat
# Processing Record 1 of Set 9 | sindou
# Processing Record 2 of Set 9 | komsomolskiy
# Processing Record 3 of Set 9 | kjollefjord
# Processing Record 4 of Set 9 | taoudenni
# Processing Record 5 of Set 9 | macau
# Processing Record 6 of Set 9 | wad madani
# Processing Record 7 of Set 9 | porkhov
# Processing Record 8 of Set 9 | haines junction
# Processing Record 9 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 9 | sherbrooke
# Processing Record 11 of Set 9 | tshikapa
# Processing Record 12 of Set 9 | naron
# Processing Record 13 of Set 9 | imeni poliny osipenko
# Processing Record 14 of Set 9 | mayo
# Processing Record 15 of Set 9 | madang
# Processing Record 16 of Set 9 | iberia
# Processing Record 17 of Set 9 | hare bay
# Processing Record 18 of Set 9 | arman
# Processing Record 19 of Set 9 | verkhnevilyuysk
# Processing Record 20 of Set 9 | ambon
# Processing Record 21 of Set 9 | kuryk
# Processing Record 22 of Set 9 | quepos
# Processing Record 23 of Set 9 | kamsack
# Processing Record 24 of Set 9 | olafsvik
# Processing Record 25 of Set 9 | yeppoon
# Processing Record 26 of Set 9 | acajutla
# Processing Record 27 of Set 9 | jurmala
# Processing Record 28 of Set 9 | dudinka
# Processing Record 29 of Set 9 | olinda
# Processing Record 30 of Set 9 | high prairie
# Processing Record 31 of Set 9 | talavera
# Processing Record 32 of Set 9 | mishelevka
# Processing Record 33 of Set 9 | touros
# Processing Record 34 of Set 9 | kahna nau
# Processing Record 35 of Set 9 | deblin
# Processing Record 36 of Set 9 | am timan
# Processing Record 37 of Set 9 | port moresby
# Processing Record 38 of Set 9 | alvand
# Processing Record 39 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 40 of Set 9 | coos bay
# Processing Record 41 of Set 9 | asau
# Processing Record 42 of Set 9 | adrar
# Processing Record 43 of Set 9 | roald
# Processing Record 44 of Set 9 | puerto escondido
# Processing Record 45 of Set 9 | mehran
# Processing Record 46 of Set 9 | safita
# Processing Record 47 of Set 9 | arlit
# Processing Record 48 of Set 9 | pavlovskaya
# Processing Record 49 of Set 9 | amos
# Processing Record 50 of Set 9 | carroll
# Processing Record 1 of Set 10 | san quintin
# Processing Record 2 of Set 10 | harlingen
# Processing Record 3 of Set 10 | semey
# Processing Record 4 of Set 10 | chicama
# Processing Record 5 of Set 10 | tual
# Processing Record 6 of Set 10 | bud
# Processing Record 7 of Set 10 | porto novo
# Processing Record 8 of Set 10 | ewa beach
# Processing Record 9 of Set 10 | nichinan
# Processing Record 10 of Set 10 | mayumba
# Processing Record 11 of Set 10 | ballina
# Processing Record 12 of Set 10 | aklavik
# Processing Record 13 of Set 10 | barcelos
# Processing Record 14 of Set 10 | cabildo
# Processing Record 15 of Set 10 | maltahohe
# Processing Record 16 of Set 10 | putyatino
# Processing Record 17 of Set 10 | kununurra
# Processing Record 18 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 19 of Set 10 | poyarkovo
# Processing Record 20 of Set 10 | taltal
# Processing Record 21 of Set 10 | vila do maio
# Processing Record 22 of Set 10 | ambilobe
# Processing Record 23 of Set 10 | ranong
# Processing Record 24 of Set 10 | kodinsk
# Processing Record 25 of Set 10 | smithers
# Processing Record 26 of Set 10 | pemangkat
# Processing Record 27 of Set 10 | half moon bay
# Processing Record 28 of Set 10 | lakes entrance
# Processing Record 29 of Set 10 | trelew
# Processing Record 30 of Set 10 | dovers
# Processing Record 31 of Set 10 | harnai
# Processing Record 32 of Set 10 | barentu
# Processing Record 33 of Set 10 | guaruja
# Processing Record 34 of Set 10 | moree
# Processing Record 35 of Set 10 | rairangpur
# Processing Record 36 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 10 | cabo san lucas
# Processing Record 38 of Set 10 | shaunavon
# Processing Record 39 of Set 10 | vestmanna
# Processing Record 40 of Set 10 | bay roberts
# Processing Record 41 of Set 10 | huanren
# Processing Record 42 of Set 10 | maumere
# Processing Record 43 of Set 10 | pemba
# Processing Record 44 of Set 10 | hilton head island
# Processing Record 45 of Set 10 | nador
# Processing Record 46 of Set 10 | noumea
# Processing Record 47 of Set 10 | bandarbeyla
# Processing Record 48 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 49 of Set 10 | prainha
# Processing Record 50 of Set 10 | asosa
# Processing Record 1 of Set 11 | lovington
# Processing Record 2 of Set 11 | panaba
# Processing Record 3 of Set 11 | taunggyi
# Processing Record 4 of Set 11 | kopavogur
# Processing Record 5 of Set 11 | husavik
# Processing Record 6 of Set 11 | mpigi
# Processing Record 7 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 8 of Set 11 | ipixuna
# Processing Record 9 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 11 | wahiawa
# Processing Record 11 of Set 11 | isangel
# Processing Record 12 of Set 11 | tromso
# Processing Record 13 of Set 11 | alihe
# Processing Record 14 of Set 11 | doha
# Processing Record 15 of Set 11 | horsham
# Processing Record 16 of Set 11 | tayshet
# Processing Record 17 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 18 of Set 11 | dzhankoy
# Processing Record 19 of Set 11 | murud
# Processing Record 20 of Set 11 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 21 of Set 11 | kangaatsiaq
# Processing Record 22 of Set 11 | asyut
# Processing Record 23 of Set 11 | lalsk
# Processing Record 24 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 25 of Set 11 | jiazi
# Processing Record 26 of Set 11 | rawah
# Processing Record 27 of Set 11 | sikasso
# Processing Record 28 of Set 11 | sayalgudi
# City not found. Skipping...
# Processing Record 29 of Set 11 | zemio
# Processing Record 30 of Set 11 | awjilah
# Processing Record 31 of Set 11 | alekseyevsk
# Processing Record 32 of Set 11 | lata
# Processing Record 33 of Set 11 | aswan
# Processing Record 34 of Set 11 | dayong
# Processing Record 35 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 37 of Set 11 | innisfail
# Processing Record 38 of Set 11 | carutapera
# Processing Record 39 of Set 11 | orlik
# Processing Record 40 of Set 11 | epiniana
# Processing Record 41 of Set 11 | kaputa
# Processing Record 42 of Set 11 | stutterheim
# Processing Record 43 of Set 11 | kapit
# Processing Record 44 of Set 11 | esmeraldas
# Processing Record 45 of Set 11 | naxos
# Processing Record 46 of Set 11 | juntas
# Processing Record 47 of Set 11 | wasco
# Processing Record 48 of Set 11 | comodoro rivadavia
# Processing Record 49 of Set 11 | chengde
# Processing Record 50 of Set 11 | firozpur jhirka
# Processing Record 1 of Set 12 | merano
# Processing Record 2 of Set 12 | uray
# Processing Record 3 of Set 12 | mitu
# Processing Record 4 of Set 12 | nong kung si
# Processing Record 5 of Set 12 | paragominas
# Processing Record 6 of Set 12 | glushkovo
# Processing Record 7 of Set 12 | mokobeng
# Processing Record 8 of Set 12 | urumqi
# Processing Record 9 of Set 12 | odweyne
# Processing Record 10 of Set 12 | simao
# Processing Record 11 of Set 12 | luorong
# Processing Record 12 of Set 12 | yebaishou
# Processing Record 13 of Set 12 | visnes
# Processing Record 14 of Set 12 | talcahuano
# Processing Record 15 of Set 12 | umm lajj
# Processing Record 16 of Set 12 | san jose
# Processing Record 17 of Set 12 | pirgos
# Processing Record 18 of Set 12 | pyay
# Processing Record 19 of Set 12 | montrose
# Processing Record 20 of Set 12 | tieli
# Processing Record 21 of Set 12 | marsh harbour
# Processing Record 22 of Set 12 | mochudi
# Processing Record 23 of Set 12 | tabou
# Processing Record 24 of Set 12 | agadez
# Processing Record 25 of Set 12 | manicore
# Processing Record 26 of Set 12 | isla mujeres
# Processing Record 27 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 12 | liminangcong
# City not found. Skipping...
# Processing Record 29 of Set 12 | la sarre
# Processing Record 30 of Set 12 | mogadishu
# Processing Record 31 of Set 12 | shetpe
# Processing Record 32 of Set 12 | melito di porto salvo
# Processing Record 33 of Set 12 | sheltozero
# Processing Record 34 of Set 12 | qeshm
# Processing Record 35 of Set 12 | shache
# Processing Record 36 of Set 12 | narrabri
# Processing Record 37 of Set 12 | bac lieu
# Processing Record 38 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 12 | coro
# Processing Record 40 of Set 12 | komsomolets
# Processing Record 41 of Set 12 | abonnema
# Processing Record 42 of Set 12 | mount isa
# Processing Record 43 of Set 12 | storforshei
# Processing Record 44 of Set 12 | huangchuan
# Processing Record 45 of Set 12 | pochutla
# Processing Record 46 of Set 12 | tepechitlan
# Processing Record 47 of Set 12 | mahanoro
# Processing Record 48 of Set 12 | ginir
# Processing Record 49 of Set 12 | coihueco
# Processing Record 50 of Set 12 | sheksna
# Processing Record 1 of Set 13 | shunyi
# Processing Record 2 of Set 13 | nabire
# Processing Record 3 of Set 13 | hami
# Processing Record 4 of Set 13 | valparaiso
# Processing Record 5 of Set 13 | antalaha
# Processing Record 6 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 13 | kortkeros
# Processing Record 8 of Set 13 | marystown
# Processing Record 9 of Set 13 | repelon
# Processing Record 10 of Set 13 | tarko-sale
# Processing Record 11 of Set 13 | ahipara
# Processing Record 12 of Set 13 | hanna
# Processing Record 13 of Set 13 | ngunguru
# Processing Record 14 of Set 13 | lerwick
# Processing Record 15 of Set 13 | la ronge
# Processing Record 16 of Set 13 | xuddur
# Processing Record 17 of Set 13 | ludvika
# Processing Record 18 of Set 13 | banjar
# Processing Record 19 of Set 13 | moranbah
# Processing Record 20 of Set 13 | kanbe
# Processing Record 21 of Set 13 | hurghada
# Processing Record 22 of Set 13 | qandala
# Processing Record 23 of Set 13 | boueni
# Processing Record 24 of Set 13 | wajima
# Processing Record 25 of Set 13 | seydi
# Processing Record 26 of Set 13 | high level
# Processing Record 27 of Set 13 | bafoulabe
# Processing Record 28 of Set 13 | galle
# Processing Record 29 of Set 13 | motygino
# Processing Record 30 of Set 13 | anito
# Processing Record 31 of Set 13 | fowa
# Processing Record 32 of Set 13 | wanlaweyn
# Processing Record 33 of Set 13 | kohlu
# Processing Record 34 of Set 13 | poum
# Processing Record 35 of Set 13 | bato
# Processing Record 36 of Set 13 | homer
# Processing Record 37 of Set 13 | auki
# Processing Record 38 of Set 13 | yanam
# Processing Record 39 of Set 13 | buraydah
# Processing Record 40 of Set 13 | khilok
# Processing Record 41 of Set 13 | salisbury
# Processing Record 42 of Set 13 | kingaroy
# Processing Record 43 of Set 13 | sola
# Processing Record 44 of Set 13 | bati
# Processing Record 45 of Set 13 | gogrial
# Processing Record 46 of Set 13 | cap-aux-meules
# Processing Record 47 of Set 13 | staryy urukh
# Processing Record 48 of Set 13 | richards bay
# Processing Record 49 of Set 13 | kalininskaya
# Processing Record 50 of Set 13 | luganville
# Processing Record 1 of Set 14 | axim
# Processing Record 2 of Set 14 | eyl
# Processing Record 3 of Set 14 | codrington
# Processing Record 4 of Set 14 | georgiyevka
# Processing Record 5 of Set 14 | ostrovnoy
# Processing Record 6 of Set 14 | waslala
# Processing Record 7 of Set 14 | lac du bonnet
# Processing Record 8 of Set 14 | elko
# Processing Record 9 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 10 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 11 of Set 14 | kalabo
# Processing Record 12 of Set 14 | domoni
# Processing Record 13 of Set 14 | port shepstone
# Processing Record 14 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 16 of Set 14 | bowen
# Processing Record 17 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 18 of Set 14 | cachira
# Processing Record 19 of Set 14 | jalingo
# Processing Record 20 of Set 14 | jahrom
# City not found. Skipping...
# Processing Record 21 of Set 14 | tura
# Processing Record 22 of Set 14 | saint-michel-des-saints
# Processing Record 23 of Set 14 | gatak
# Processing Record 24 of Set 14 | nantucket
# Processing Record 25 of Set 14 | kuliyapitiya
# Processing Record 26 of Set 14 | brookhaven
# Processing Record 27 of Set 14 | poso
# Processing Record 28 of Set 14 | mangrol
# Processing Record 29 of Set 14 | turinsk
# Processing Record 30 of Set 14 | livingstonia
# Processing Record 31 of Set 14 | ahome
# Processing Record 32 of Set 14 | havre
# Processing Record 33 of Set 14 | plonsk
# Processing Record 34 of Set 14 | san cristobal
# Processing Record 35 of Set 14 | yerbogachen
# Processing Record 36 of Set 14 | jatai
# Processing Record 37 of Set 14 | sobolevo
# Processing Record 38 of Set 14 | kibala
# Processing Record 39 of Set 14 | felanitx
# Processing Record 40 of Set 14 | tucuman
# Processing Record 41 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 42 of Set 14 | kantang
# Processing Record 43 of Set 14 | keetmanshoop
# Processing Record 44 of Set 14 | roebourne
# Processing Record 45 of Set 14 | zenzeli
# Processing Record 46 of Set 14 | honningsvag
# Processing Record 47 of Set 14 | anklam
# Processing Record 48 of Set 14 | tulsipur
# Processing Record 49 of Set 14 | esna
# Processing Record 50 of Set 14 | lawan kuda baharu
# City not found. Skipping...
# Processing Record 1 of Set 15 | karratha
# Processing Record 2 of Set 15 | san nicolas
# Processing Record 3 of Set 15 | kerki
# City not found. Skipping...
# Processing Record 4 of Set 15 | ndouci
# City not found. Skipping...
# Processing Record 5 of Set 15 | black forest
# Processing Record 6 of Set 15 | san ignacio
# Processing Record 7 of Set 15 | zhigalovo
# Processing Record 8 of Set 15 | hof
# Processing Record 9 of Set 15 | lukovetskiy
# Processing Record 10 of Set 15 | pavilosta
# Processing Record 11 of Set 15 | wanaka
# Processing Record 12 of Set 15 | anloga
# Processing Record 13 of Set 15 | zachary
# Processing Record 14 of Set 15 | nisia floresta
# Processing Record 15 of Set 15 | one hundred mile house
# City not found. Skipping...
# Processing Record 16 of Set 15 | mwinilunga
# Processing Record 17 of Set 15 | sao felix do xingu
# Processing Record 18 of Set 15 | batagay
# Processing Record 19 of Set 15 | tamisan
# Processing Record 20 of Set 15 | dire
# Processing Record 21 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 23 of Set 15 | machali
# Processing Record 24 of Set 15 | kitakata
# Processing Record 25 of Set 15 | laem sing
# Processing Record 26 of Set 15 | khormuj
# City not found. Skipping...
# Processing Record 27 of Set 15 | rudsar
# Processing Record 28 of Set 15 | ouallam
# Processing Record 29 of Set 15 | kolondieba
# Processing Record 30 of Set 15 | portsmouth
# Processing Record 31 of Set 15 | kandrian
# Processing Record 32 of Set 15 | tahe
# Processing Record 33 of Set 15 | bubaque
# Processing Record 34 of Set 15 | wajir
# Processing Record 35 of Set 15 | imbituba
# Processing Record 36 of Set 15 | mulege
# Processing Record 37 of Set 15 | oktyabrskiy
# Processing Record 38 of Set 15 | san ramon
# Processing Record 39 of Set 15 | padang
# Processing Record 40 of Set 15 | ust-kuyga
# Processing Record 41 of Set 15 | simeonovgrad
# Processing Record 42 of Set 15 | chalon-sur-saone
# Processing Record 43 of Set 15 | boo
# Processing Record 44 of Set 15 | akdepe
# Processing Record 45 of Set 15 | kijang
# Processing Record 46 of Set 15 | saint george
# Processing Record 47 of Set 15 | san carlos
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df= pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Hamilton  39.1834  -84.5333     80.78        49         100        1.01
# 1       Narsaq  60.9167  -46.0500     34.02        45           0        3.51
# 2    Seryshevo  51.0933  128.3786     34.34        91          72        5.93
# 3      Panguna  -6.3164  155.4848     70.00        95          99        2.17
# 4  Orange Cove  36.6244 -119.3137     86.85        24           1        4.61
# 5    Cape Town -33.9258   18.4232     61.27        76           0        9.46
# 6       Harper   4.3750   -7.7169     77.61        85          54        6.62
# 7       Nemuro  43.3236  145.5750     61.23        94          81        6.55
# 8       Atuona  -9.8000 -139.0333     78.12        69           7       17.67
# 9      Margate  51.3813    1.3862     61.30        77         100        5.01
#
#   Country Current_Description
# 0      US     overcast clouds
# 1      GL           clear sky
# 2      RU       broken clouds
# 3      PG          light rain
# 4      US           clear sky
# 5      ZA           clear sky
# 6      LR       broken clouds
# 7      JP       broken clouds
# 8      PF           clear sky
# 9      GB     overcast clouds

# %%
city_data_df = city_data_df[["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current_Description"]]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Hamilton      US  39.1834  -84.5333     80.78        49         100
# 1       Narsaq      GL  60.9167  -46.0500     34.02        45           0
# 2    Seryshevo      RU  51.0933  128.3786     34.34        91          72
# 3      Panguna      PG  -6.3164  155.4848     70.00        95          99
# 4  Orange Cove      US  36.6244 -119.3137     86.85        24           1
# 5    Cape Town      ZA -33.9258   18.4232     61.27        76           0
# 6       Harper      LR   4.3750   -7.7169     77.61        85          54
# 7       Nemuro      JP  43.3236  145.5750     61.23        94          81
# 8       Atuona      PF  -9.8000 -139.0333     78.12        69           7
# 9      Margate      GB  51.3813    1.3862     61.30        77         100
#
#    Wind Speed Current_Description
# 0        1.01     overcast clouds
# 1        3.51           clear sky
# 2        5.93       broken clouds
# 3        2.17          light rain
# 4        4.61           clear sky
# 5        9.46           clear sky
# 6        6.62       broken clouds
# 7        6.55       broken clouds
# 8       17.67           clear sky
# 9        5.01     overcast clouds

# %%
# Create the output file (CSV).
output_file = ("weather_database/WeatherPy_Database.csv")
# Export the City_Data into a CSV.
city_data_df.to_csv(output_file, index_label="City_ID")
